# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##  💾 Train Set

# %%
dataframe = pd.read_csv('/media/data/DATA_OVRDT/CSV/azure_ovrdtDB_Alllevel_6900imgs_round1234_train_split5fold.csv')
print(dataframe.shape)
dataframe.head()
# Out:
# (6900, 12)
#    Unnamed: 0            fileName  class  \
# 0           0  udfrumsujl.png.jpg    0.0
# 1           1  vadnlwjsbk.png.jpg    0.0
# 2           2  dtmvydboay.png.jpg    0.0
# 3           3  wdvkvredan.png.jpg    0.0
# 4           4  toxxggmkbv.png.jpg    0.0
#
#                                                 path  \
# 0  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/ovrd...
# 1  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/ovrd...
# 2  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/ovrd...
# 3  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/ovrd...
# 4  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/ovrd...
#
#                                        path_filename  ov_level   ov  \
# 0  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/imag...       0.0  0.0
# 1  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/imag...       0.0  0.0
# 2  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/imag...       0.0  0.0
# 3  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/imag...       1.0  1.0
# ...

# %%
#dataframe['path_filename'].tolist()

# %%
dataframe['path'] = dataframe['path'].str.replace('tohn/HDD/VISION_dataset','data')
dataframe['path_filename'] = dataframe['path_filename'].str.replace('tohn/HDD/VISION_dataset','data')
dataframe['path_crop'] = dataframe['path_crop'].str.replace('tohn/HDD/VISION_dataset','data')

# %%
dataframe.head()
# Out:
#    Unnamed: 0            fileName  class  \
# 0           0  udfrumsujl.png.jpg    0.0
# 1           1  vadnlwjsbk.png.jpg    0.0
# 2           2  dtmvydboay.png.jpg    0.0
# 3           3  wdvkvredan.png.jpg    0.0
# 4           4  toxxggmkbv.png.jpg    0.0
#
#                                                 path  \
# 0  /media/data/DATA_OVRDT/ovrdtDB_08_06_65_from_A...
# 1  /media/data/DATA_OVRDT/ovrdtDB_08_06_65_from_A...
# 2  /media/data/DATA_OVRDT/ovrdtDB_08_06_65_from_A...
# 3  /media/data/DATA_OVRDT/ovrdtDB_08_06_65_from_A...
# 4  /media/data/DATA_OVRDT/ovrdtDB_08_06_65_from_A...
#
#                                        path_filename  ov_level   ov  \
# 0  /media/data/DATA_OVRDT/images_azure_08_06_65/u...       0.0  0.0
# 1  /media/data/DATA_OVRDT/images_azure_08_06_65/v...       0.0  0.0
# 2  /media/data/DATA_OVRDT/images_azure_08_06_65/d...       0.0  0.0
# 3  /media/data/DATA_OVRDT/images_azure_08_06_65/w...       1.0  1.0
# ...

# %%
dataframe.to_csv('/media/data/DATA_OVRDT/CSV/azure_ovrdtDB_Alllevel_6900imgs_round1234_train_split5fold.csv')

# %% [markdown]
# ##  💾 Test Set

# %%
testframe = pd.read_csv('/media/data/DATA_OVRDT/CSV/azure_ovrdtDB_Alllevel_1724imgs_round1234_test.csv')
print('Ov Class :', set(testframe['class']))
print(f'Test Data Shape [ {testframe.shape} ]')
testframe.head(3)
# Out:
# Ov Class : {0.0, 1.0, 2.0, 3.0, 4.0}
# Test Data Shape [ (1724, 11) ]
#    Unnamed: 0                                  fileName  class  \
# 0         701                        dquemcuexa.png.jpg    0.0
# 1         702  6078D6A9-5301-4130-9007-2B60C16D7374.jpg    0.0
# 2         703                        dbvemfjorv.png.jpg    0.0
#
#                                                 path  \
# 0  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/ovrd...
# 1  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/ovrd...
# 2  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/ovrd...
#
#                                        path_filename  ov_level   ov  \
# 0  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/imag...       0.0  0.0
# 1  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/imag...       0.0  0.0
# 2  /media/tohn/HDD/VISION_dataset/DATA_OVRDT/imag...       1.0  1.0
#
#                                            path_crop  OSofRec  Round  data
# ...

# %%
testframe['path'] = testframe['path'].str.replace('tohn/HDD/VISION_dataset','data')
testframe['path_filename'] = testframe['path_filename'].str.replace('tohn/HDD/VISION_dataset','data')
testframe['path_crop'] = testframe['path_crop'].str.replace('tohn/HDD/VISION_dataset','data')

# %%
testframe.head(3)
# Out:
#    Unnamed: 0                                  fileName  class  \
# 0         701                        dquemcuexa.png.jpg    0.0
# 1         702  6078D6A9-5301-4130-9007-2B60C16D7374.jpg    0.0
# 2         703                        dbvemfjorv.png.jpg    0.0
#
#                                                 path  \
# 0  /media/data/DATA_OVRDT/ovrdtDB_08_06_65_from_A...
# 1  /media/data/DATA_OVRDT/ovrdtDB_08_06_65_from_A...
# 2  /media/data/DATA_OVRDT/ovrdtDB_08_06_65_from_A...
#
#                                        path_filename  ov_level   ov  \
# 0  /media/data/DATA_OVRDT/images_azure_08_06_65/d...       0.0  0.0
# 1  /media/data/DATA_OVRDT/images_azure_08_06_65/6...       0.0  0.0
# 2  /media/data/DATA_OVRDT/images_azure_08_06_65/d...       1.0  1.0
#
#                                            path_crop  OSofRec  Round  data
# 0  /media/data/DATA_OVRDT/images_azure_08_06_65_c...  Android    1.0  test
# ...

# %%
testframe.to_csv('/media/data/DATA_OVRDT/CSV/azure_ovrdtDB_Alllevel_1724imgs_round1234_test.csv')
